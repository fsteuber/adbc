# %%
#! The following code is intented only for illustration and cannot be run as a single script.
import numpy as np
from multiprocessing import Queue
import pandas as pd
import redis
import time
import datetime
import matplotlib.pyplot as plt
import pickle
import os
from os.path import join, isfile
from os import listdir
import seaborn as sns
sns.set()
from itertools import product
import warnings
warnings.filterwarnings('ignore')
import matplotlib.backends.backend_pdf
from tqdm import tqdm
from scipy.stats import zscore, linregress
import pickle
from sklearn.cluster import DBSCAN

# %%
def convolve(timeseries, window_small, window_large, bin_size=5, min_occurrences=600):

    series1 = np.convolve(timeseries, np.ones(int(window_small/bin_size)), mode="valid")
    series2 = np.convolve(timeseries, np.ones(int(window_large/bin_size)), mode="valid")
        
    stride = series1.shape[0] - series2.shape[0]
    series1 = series1[stride:]

    result = np.nan_to_num(series1 / series2, nan=0.) * (window_large/window_small)
    result[result == 0] = 1

    # two sided anomalies
    #pos = np.where(result < 1)[0]
    #result[pos] = 1/result[pos]
    
    #print(result)
    
    f = lambda n: 1/(1+np.e**-n)  # normalize to [0;1]
    
    return np.array(list(map(f, result)))

# %%
def convolve_zscore(timeseries, window_small, window_large, bin_size=5, min_occurrences=600):
    
    length = timeseries.shape[0] - int(window_large/bin_size)
    result = np.zeros(length)

    for i in range(length):
        series = timeseries[i:i + int(window_large/bin_size)]
        result[i] = np.abs(zscore(series)[-1])

    f = lambda n: 1/(1+np.e**-n)  # normalize to [0;1]
    
    return np.array(list(map(f, result)))

# %%
def convolve_residual(timeseries, window_small, window_large, bin_size=5, min_occurrences=600):
    
    length = timeseries.shape[0] - int(window_large/bin_size)
    result = np.zeros(length)
    x = np.array([i for i in range(int(window_large/bin_size))])

    for i in range(length):
        series = np.asarray(timeseries[i:i + int(window_large/bin_size)])
        reg = linregress(x, series)
        m = reg.slope
        t = reg.intercept
           
        residual = series[-1] - (m * int(window_large/bin_size) + t)
        residual *= residual
        result[i] = max(residual, 1)
                    
    result = np.log(result)
    f = lambda n: 1/(1+np.e**-n)  # normalize to [0;1]
    
    return np.array(list(map(f, result)))

# %%
def thresholds(ratios, memory_size=12*5*24, percentile=90):
    N = int(memory_size / 5)
    percentiles = []
    
    for i in range(len(ratios) - N):
        percentiles.append(np.percentile(ratios[i:i+N], percentile))
        
    percentiles = np.asarray(percentiles)
    percentiles[percentiles == np.inf] = 0
    
    return percentiles

# %%
def temporal_clustering(percentile=95, minSamples=3, eps=600):
    path = "/home/../realTweets/"

    df = pd.DataFrame(columns=["timestamp", "value", "anomaly_score", "token"])

    files = [join("tmp/", f) for f in listdir("tmp/") if isfile(join("tmp/", f))]

    for file in files:
        tmp = pd.read_csv(file, delimiter=",")
        tmp = tmp[["timestamp", "value", "anomaly_score"]]
        tmp["token"] = file.split("volume_")[-1].split(".")[0]
        df = pd.concat((df, tmp))
        
    for token in df["token"].unique():

        # filter on timestamps where anomaly_score > threshold
        df_ = df[df["token"] == token]
        threshold = np.nanpercentile(df_["anomaly_score"], percentile)
        relevant_idx = np.where(df_["anomaly_score"] > threshold)[0]
        df_ = df_.iloc[relevant_idx]
        
        

        # convert string date to timestamp
        f = lambda n: int(time.mktime(datetime.datetime.strptime(n, "%Y-%m-%d %H:%M:%S").timetuple()))
        timestamps = df_["timestamp"].apply(lambda n: f(n))

        # temporal clustering
        ts = np.asarray(sorted(timestamps)).reshape(-1, 1)
        # dbscan = DBSCAN(min_samples=minSamples, eps=max(eps, minSamples*300)).fit(ts)
        dbscan = DBSCAN(min_samples=minSamples, eps=minSamples*eps).fit(ts)
        labels = dbscan.labels_

        # adjust anomaly scores for clustered anomalies:
        idx = np.where(labels > -1)

        # TODO: extrahierte Daten müssen noch in die relevanten Zeiträume zurückgeschrieben werden
        df_ = df[df["token"] == token]
        relevant_idx = relevant_idx[idx[0]]
        df_.loc[relevant_idx, "anomaly_score"] = 1  #(2/3)
        #df_.loc[~relevant_idx, "anomaly_score"] **= (1/2)

        # re-persist data
        path = "/home/../realTweets/adbc_Twitter_volume_" + token + ".csv"
        df_ = df_.drop(['token'], axis=1)
        df_.to_csv(path)

# %%
def process_dataset(path_to_dataset, path_to_output_file, p_small, p_large, detector, pdf=None):

    # general parameters
    window_small = p_small
    window_large = p_large

    # load data
    df = pd.read_csv(path_to_dataset)
    df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y-%m-%d %H:%M:%S')
    
    scores = None

    
    # convolutions
    if detector == "ratio":
        scores_ratio = convolve(df["value"], window_small, window_large)[1:]
        scores = scores_ratio
    elif detector == "zscore":
        scores_zscore = convolve_zscore(df["value"], window_small, window_large)
        scores = scores_zscore
    elif detector == "residual":
        scores_residual = convolve_residual(df["value"], window_small, window_large)    
        scores = scores_residual
    elif detector == "combined":
        scores_ratio = convolve(df["value"], window_small, window_large)[1:]
        scores_zscore = convolve_zscore(df["value"], window_small, window_large)
        scores_residual = convolve_residual(df["value"], window_small, window_large)
        scores = (scores_ratio * scores_zscore * scores_residual) ** (1/3)
    elif detector == "two":
        scores_ratio = convolve(df["value"], window_small, window_large)[1:]
        scores_zscore = convolve_zscore(df["value"], window_small, window_large)
        scores = (scores_ratio * scores_zscore) ** (1/2)

    else:
        print("Invalid detector found: {}. Please choose from ['ratio', 'zscore', 'residual']".format(detector))

    stride = df.shape[0] - scores.shape[0]
    scores = np.insert(scores, 0, [0] * stride, axis=0)
    df["anomaly_score"] = scores
    
    # write results to csv
    df.to_csv(path_to_output_file, sep=",", index=False)
    df.to_csv("tmp/" + path_to_output_file.split("/")[-1], sep=",", index=False)
    
    # optional plotting
    if pdf is not None: 
        # plot original timeseries
        sns.set(rc={'figure.figsize':(15.7,8.27)})
        fig, ax1 = plt.subplots()
        ax2 = ax1.twinx()
        sns.lineplot(x="timestamp", y="value", data=df, ax=ax1)

        percentile=95

        # plot confidence bands
        t_upper = thresholds(scores, percentile=percentile)
        t_lower = thresholds(scores, percentile=100-percentile)

        stride = df.shape[0] - t_upper.shape[0]

        #ax2.tick_params(axis="y", labelcolor="red")
        ax2.plot(df["timestamp"][stride:], t_lower, color="black", alpha=0.3)
        ax2.plot(df["timestamp"][stride:], t_upper, color="black", alpha=0.3)
        ax2.fill_between(df["timestamp"][stride:], t_lower, t_upper, alpha=0.2, color="black")

        # plot convolutions
        sns.lineplot(x="timestamp", y="anomaly_score", data=df, color="red",  linewidth=1, ax=ax2, alpha=0.4)
        ax2.set_ylabel("Ratio")
        ax2.tick_params(axis="y", labelcolor="red")
        # ax2.set_ylim([-.3, window_large/window_small * 1.2])
        #ax2.set_ylim([-3.5, 3.5])



        # plot anomaly circles
        x_anom = np.squeeze(np.argwhere(scores[stride:] > t_upper))
        y_anom = scores[stride:][x_anom]

        ax2.scatter(df["timestamp"][stride:].iloc[x_anom], y_anom, color="k")


        plt.title("Visual Results for '{}' (Conv: {}/{}) {}@{}".format("/".join(path_to_dataset.split("/")[-2:]), p_small, p_large, y_anom.shape[0], percentile))
        #plt.savefig(path_to_output_file.replace("csv", "pdf").replace("results", "plots"), bbox_inches='tight')
        pdf.savefig(fig, bbox_inches='tight')

# %%
path_to_nab = "/home/../NAB/"
algo_name = "adbc"
path_to_own_algo = join(path_to_nab + "results/", algo_name)
verbosity = 0

pdf = matplotlib.backends.backend_pdf.PdfPages("anomaly_plots.pdf")

# create folders for plots
try:
    os.mkdir(join(path_to_nab, "plots"))
except:
    ...

try:
    os.mkdir(join(path_to_nab + "plots", algo_name))
except:
    ...

# create folders for algorithm if not present yet
existing_algorithms = [f for f in os.listdir(path_to_nab + "results/") if not isfile(join(path_to_nab + "results/", f))]

if algo_name not in existing_algorithms:
    os.mkdir(path_to_own_algo)


# iterate over all dataset folders
dataset_folders = [f for f in os.listdir(path_to_nab + "data/") if not isfile(join(path_to_nab + "data/", f))]


results = {}
# grid search
vals_small = [5,10,30]
#vals_large = list(np.arange(60, 60*24*4, 60))
vals_large = [720,1440,2160,2880,3600,4320,5040,5760]
detectors = ["zscore", "ratio", "residual", "combined", "two"]


for detector in detectors:

    for s, l in tqdm(product(vals_small, vals_large)):
            
        if s > 5 and detector != "ratio":
            continue

        if verbosity >= 1:
            print("Starting GridSearch - Params: {}/{} with detector {}".format(s, l, detector))

        for folder in dataset_folders[-1:]:

            # create folders for algorithm results if not present yet
            try:
                os.mkdir(join(path_to_own_algo, folder))
            except:
                ...
            try:
                os.mkdir(join(join(path_to_nab + "plots", algo_name), folder))
            except:
                ...

            if verbosity >= 2:
                print("Currently processing Datasets from Folder '{}'.".format(folder))

            # process individual datasets
            datasets = [f for f in os.listdir(join(path_to_nab + "data/", folder)) if isfile(join(join(path_to_nab + "data/", folder), f))]

            for dataset in datasets[:]:
                if verbosity >= 2:
                    print("Next Dataset: '{}'".format(dataset))
                path_to_dataset = join(join(path_to_nab + "data/", folder), dataset)
                path_to_output_file = join(join(path_to_own_algo, folder), algo_name + "_" + dataset)
                #process_dataset(path_to_dataset, path_to_output_file, s, l, pdf)  
                process_dataset(path_to_dataset, path_to_output_file, s, l, detector)  
                
        # benchmark results
        command = "cd NAB/; python3 run.py -d adbc --optimize --score --normalize --skipConfirmation"
        ret = os.popen(command).read()

        acc = -1
        fp = -1
        fn = -1

        for r in ret.split("\n"):
            if "standard' profile = " in r:
                acc = float(r.split("standard' profile = ")[-1])
            elif "reward_low_FP_rate' profile = " in r:
                fp = float(r.split("reward_low_FP_rate' profile = ")[-1])
            elif "reward_low_FN_rate' profile = " in r:
                fn = float(r.split("reward_low_FN_rate' profile = ")[-1])

        results[len(results)] = {"detector": detector,
                                 "params": {"window_small": s, "window_large": l}, 
                                 "results": {"acc": acc, "fp": fp, "fn": fn},
                                "clustering": False}


        if verbosity >= 0:
            print("Baseline Results for GridSearch - Params: {}/{} with detector {} - Acc: {}, FP: {}, FN: {}".format(s, l, detector, acc, fp, fn))
                
        # apply clustering
        for perc in [98, 98.5, 99, 99.5, 99.6, 99.7, 99.8, 99.9]:
            for minSamples in list(np.arange(8, 20, 1)):
                for eps in [300, 450, 600, 750]:

                    temporal_clustering(percentile=perc, minSamples=minSamples, eps=eps)

                    # benchmark results
                    command = "cd NAB/; python3 run.py -d adbc --optimize --score --normalize --skipConfirmation"
                    ret = os.popen(command).read()

                    acc = -1
                    fp = -1
                    fn = -1

                    for r in ret.split("\n"):
                        if "standard' profile = " in r:
                            acc = float(r.split("standard' profile = ")[-1])
                        elif "reward_low_FP_rate' profile = " in r:
                            fp = float(r.split("reward_low_FP_rate' profile = ")[-1])
                        elif "reward_low_FN_rate' profile = " in r:
                            fn = float(r.split("reward_low_FN_rate' profile = ")[-1])

                    results[len(results)] = {"detector": detector,
                                             "params": {"window_small": s, "window_large": l}, 
                                             "results": {"acc": acc, "fp": fp, "fn": fn},
                                            "clustering": True,
                                            "percentile": perc,
                                            "minSamples": minSamples,
                                            "eps": eps}


                    if verbosity >= 0:
                        print(perc, minSamples, eps)
                        print("Clustering Results for GridSearch - Params: {}/{} with detector {} - Acc: {}, FP: {}, FN: {}".format(s, l, detector, acc, fp, fn))


pickle.dump(results, open("results_with_clustering.pcl","wb"))  # all three detectors
# pickle.dump(results, open("results_two_detectors_one_sided.pcl","wb"))  # best two detectors
# pickle.dump(results, open("results_detector.pcl","wb"))  # individual detectors

pdf.close()
# Out:
# 0it [00:00, ?it/s]
# Baseline Results for GridSearch - Params: 5/720 with detector zscore - Acc: 50.31, FP: 47.3, FN: 64.25
# 98 8 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.31, FP: 41.77, FN: 62.95
# 98 8 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 46.98, FP: 39.11, FN: 62.07
# 98 8 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 44.54, FP: 35.78, FN: 60.72
# 98 8 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 43.79, FP: 35.78, FN: 60.23
# 98 9 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 49.35, FP: 43.73, FN: 63.65
# 98 9 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.35, FP: 41.73, FN: 62.98
# 98 9 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 45.4, FP: 35.83, FN: 61.02
# 98 9 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 44.42, FP: 35.78, FN: 60.36
# 98 10 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.14, FP: 42.14, FN: 62.56
# 98 10 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.46, FP: 41.84, FN: 63.05
# 98 10 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 47.47, FP: 39.85, FN: 62.39
# 98 10 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 46.91, FP: 38.73, FN: 62.02
# 98 11 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 49.33, FP: 44.52, FN: 63.35
# 98 11 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.88, FP: 43.5, FN: 63.05
# 98 11 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.8, FP: 43.32, FN: 62.99
# 98 11 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.28, FP: 42.28, FN: 62.65
# 98 12 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.51, FP: 43.7, FN: 63.05
# 98 12 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.71, FP: 43.28, FN: 62.93
# 98 12 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.8, FP: 43.32, FN: 62.99
# 98 12 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.8, FP: 43.32, FN: 63.0
# 98 13 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 49.07, FP: 44.82, FN: 63.42
# 98 13 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 49.27, FP: 44.41, FN: 63.31
# 98 13 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.66, FP: 43.18, FN: 62.9
# 98 13 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 48.67, FP: 43.19, FN: 62.9
# 98 14 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 50.3, FP: 47.29, FN: 64.24
# 98 14 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.12, FP: 48.1, FN: 64.54
# 98 14 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.11, FN: 64.55
# 98 14 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.12, FN: 64.55
# 98 15 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.12, FP: 48.1, FN: 64.54
# 98 15 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.12, FP: 48.1, FN: 64.54
# 98 15 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.12, FN: 64.55
# 98 15 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.12, FN: 64.55
# 98 16 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 50.3, FP: 47.29, FN: 64.24
# 98 16 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.12, FP: 48.1, FN: 64.54
# 98 16 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.12, FN: 64.55
# 98 16 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.12, FN: 64.55
# 98 17 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 50.3, FP: 47.29, FN: 64.24
# 98 17 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 50.3, FP: 47.29, FN: 64.24
# 98 17 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.12, FN: 64.55
# 98 17 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.12, FN: 64.55
# 98 18 300
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 50.3, FP: 47.29, FN: 64.24
# 98 18 450
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 50.3, FP: 47.29, FN: 64.24
# 98 18 600
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.12, FN: 64.55
# 98 18 750
# Clustering Results for GridSearch - Params: 5/720 with detector zscore - Acc: 51.13, FP: 48.12, FN: 64.55

# %%
results
# Out:
# {0: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': False},
#  1: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 8,
#   'eps': 300},
#  2: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 8,
#   'eps': 450},
#  3: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 8,
#   'eps': 600},
#  4: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 8,
#   'eps': 750},
#  5: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 9,
#   'eps': 300},
#  6: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 9,
#   'eps': 450},
#  7: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 9,
#   'eps': 600},
#  8: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 9,
#   'eps': 750},
#  9: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 10,
#   'eps': 300},
#  10: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 10,
#   'eps': 450},
#  11: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 10,
#   'eps': 600},
#  12: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 10,
#   'eps': 750},
#  13: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 11,
#   'eps': 300},
#  14: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 11,
#   'eps': 450},
#  15: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 11,
#   'eps': 600},
#  16: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 11,
#   'eps': 750},
#  17: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 12,
#   'eps': 300},
#  18: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 12,
#   'eps': 450},
#  19: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 12,
#   'eps': 600},
#  20: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 12,
#   'eps': 750},
#  21: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 13,
#   'eps': 300},
#  22: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 13,
#   'eps': 450},
#  23: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 13,
#   'eps': 600},
#  24: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 13,
#   'eps': 750},
#  25: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 14,
#   'eps': 300},
#  26: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 14,
#   'eps': 450},
#  27: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 14,
#   'eps': 600},
#  28: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 14,
#   'eps': 750},
#  29: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 15,
#   'eps': 300},
#  30: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 15,
#   'eps': 450},
#  31: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 15,
#   'eps': 600},
#  32: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 15,
#   'eps': 750},
#  33: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 16,
#   'eps': 300},
#  34: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 16,
#   'eps': 450},
#  35: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 16,
#   'eps': 600},
#  36: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 16,
#   'eps': 750},
#  37: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 17,
#   'eps': 300},
#  38: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 17,
#   'eps': 450},
#  39: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 17,
#   'eps': 600},
#  40: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 17,
#   'eps': 750},
#  41: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 18,
#   'eps': 300},
#  42: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 18,
#   'eps': 450},
#  43: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 18,
#   'eps': 600},
#  44: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 18,
#   'eps': 750},
#  45: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 19,
#   'eps': 300},
#  46: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 19,
#   'eps': 450},
#  47: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 19,
#   'eps': 600},
#  48: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.5,
#   'minSamples': 19,
#   'eps': 750},
#  49: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 8,
#   'eps': 300},
#  50: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 8,
#   'eps': 450},
#  51: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 8,
#   'eps': 600},
#  52: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 8,
#   'eps': 750},
#  53: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 9,
#   'eps': 300},
#  54: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 9,
#   'eps': 450},
#  55: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 9,
#   'eps': 600},
#  56: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 9,
#   'eps': 750},
#  57: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 10,
#   'eps': 300},
#  58: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 10,
#   'eps': 450},
#  59: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 10,
#   'eps': 600},
#  60: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 10,
#   'eps': 750},
#  61: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 11,
#   'eps': 300},
#  62: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 11,
#   'eps': 450},
#  63: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 11,
#   'eps': 600},
#  64: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 11,
#   'eps': 750},
#  65: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 12,
#   'eps': 300},
#  66: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 12,
#   'eps': 450},
#  67: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 12,
#   'eps': 600},
#  68: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 12,
#   'eps': 750},
#  69: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 13,
#   'eps': 300},
#  70: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 13,
#   'eps': 450},
#  71: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 13,
#   'eps': 600},
#  72: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 13,
#   'eps': 750},
#  73: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 14,
#   'eps': 300},
#  74: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 14,
#   'eps': 450},
#  75: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 14,
#   'eps': 600},
#  76: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 14,
#   'eps': 750},
#  77: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 15,
#   'eps': 300},
#  78: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 15,
#   'eps': 450},
#  79: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 15,
#   'eps': 600},
#  80: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 15,
#   'eps': 750},
#  81: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 16,
#   'eps': 300},
#  82: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 16,
#   'eps': 450},
#  83: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 16,
#   'eps': 600},
#  84: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 16,
#   'eps': 750},
#  85: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 17,
#   'eps': 300},
#  86: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 17,
#   'eps': 450},
#  87: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 17,
#   'eps': 600},
#  88: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 17,
#   'eps': 750},
#  89: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 18,
#   'eps': 300},
#  90: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 18,
#   'eps': 450},
#  91: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 18,
#   'eps': 600},
#  92: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 18,
#   'eps': 750},
#  93: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 19,
#   'eps': 300},
#  94: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 19,
#   'eps': 450},
#  95: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 19,
#   'eps': 600},
#  96: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.6,
#   'minSamples': 19,
#   'eps': 750},
#  97: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 8,
#   'eps': 300},
#  98: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 8,
#   'eps': 450},
#  99: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 8,
#   'eps': 600},
#  100: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 8,
#   'eps': 750},
#  101: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 9,
#   'eps': 300},
#  102: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 9,
#   'eps': 450},
#  103: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 9,
#   'eps': 600},
#  104: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 9,
#   'eps': 750},
#  105: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 10,
#   'eps': 300},
#  106: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 10,
#   'eps': 450},
#  107: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 10,
#   'eps': 600},
#  108: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 10,
#   'eps': 750},
#  109: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 11,
#   'eps': 300},
#  110: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 11,
#   'eps': 450},
#  111: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 11,
#   'eps': 600},
#  112: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 11,
#   'eps': 750},
#  113: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 12,
#   'eps': 300},
#  114: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 12,
#   'eps': 450},
#  115: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 12,
#   'eps': 600},
#  116: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 12,
#   'eps': 750},
#  117: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 13,
#   'eps': 300},
#  118: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 13,
#   'eps': 450},
#  119: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 13,
#   'eps': 600},
#  120: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 13,
#   'eps': 750},
#  121: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 14,
#   'eps': 300},
#  122: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 14,
#   'eps': 450},
#  123: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 14,
#   'eps': 600},
#  124: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 14,
#   'eps': 750},
#  125: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 15,
#   'eps': 300},
#  126: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 15,
#   'eps': 450},
#  127: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 15,
#   'eps': 600},
#  128: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 15,
#   'eps': 750},
#  129: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 16,
#   'eps': 300},
#  130: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 16,
#   'eps': 450},
#  131: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 16,
#   'eps': 600},
#  132: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 16,
#   'eps': 750},
#  133: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 17,
#   'eps': 300},
#  134: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 17,
#   'eps': 450},
#  135: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 17,
#   'eps': 600},
#  136: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 17,
#   'eps': 750},
#  137: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 18,
#   'eps': 300},
#  138: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 18,
#   'eps': 450},
#  139: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 18,
#   'eps': 600},
#  140: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 18,
#   'eps': 750},
#  141: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 19,
#   'eps': 300},
#  142: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 19,
#   'eps': 450},
#  143: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 19,
#   'eps': 600},
#  144: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.7,
#   'minSamples': 19,
#   'eps': 750},
#  145: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 8,
#   'eps': 300},
#  146: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 8,
#   'eps': 450},
#  147: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 8,
#   'eps': 600},
#  148: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 8,
#   'eps': 750},
#  149: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 9,
#   'eps': 300},
#  150: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 9,
#   'eps': 450},
#  151: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 9,
#   'eps': 600},
#  152: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 9,
#   'eps': 750},
#  153: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 10,
#   'eps': 300},
#  154: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 10,
#   'eps': 450},
#  155: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 10,
#   'eps': 600},
#  156: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 10,
#   'eps': 750},
#  157: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 11,
#   'eps': 300},
#  158: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 11,
#   'eps': 450},
#  159: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 11,
#   'eps': 600},
#  160: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 11,
#   'eps': 750},
#  161: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 12,
#   'eps': 300},
#  162: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 12,
#   'eps': 450},
#  163: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 12,
#   'eps': 600},
#  164: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 12,
#   'eps': 750},
#  165: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 13,
#   'eps': 300},
#  166: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 13,
#   'eps': 450},
#  167: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 13,
#   'eps': 600},
#  168: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 13,
#   'eps': 750},
#  169: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 14,
#   'eps': 300},
#  170: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 14,
#   'eps': 450},
#  171: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 14,
#   'eps': 600},
#  172: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 14,
#   'eps': 750},
#  173: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 15,
#   'eps': 300},
#  174: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 15,
#   'eps': 450},
#  175: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 15,
#   'eps': 600},
#  176: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 15,
#   'eps': 750},
#  177: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 16,
#   'eps': 300},
#  178: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 16,
#   'eps': 450},
#  179: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 16,
#   'eps': 600},
#  180: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 16,
#   'eps': 750},
#  181: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 17,
#   'eps': 300},
#  182: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 17,
#   'eps': 450},
#  183: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 17,
#   'eps': 600},
#  184: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 17,
#   'eps': 750},
#  185: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 18,
#   'eps': 300},
#  186: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 18,
#   'eps': 450},
#  187: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 18,
#   'eps': 600},
#  188: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 18,
#   'eps': 750},
#  189: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 19,
#   'eps': 300},
#  190: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 19,
#   'eps': 450},
#  191: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 19,
#   'eps': 600},
#  192: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 19,
#   'eps': 750},
#  193: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 8,
#   'eps': 300},
#  194: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 8,
#   'eps': 450},
#  195: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 8,
#   'eps': 600},
#  196: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 8,
#   'eps': 750},
#  197: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 9,
#   'eps': 300},
#  198: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 9,
#   'eps': 450},
#  199: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 9,
#   'eps': 600},
#  200: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 9,
#   'eps': 750},
#  201: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 10,
#   'eps': 300},
#  202: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 10,
#   'eps': 450},
#  203: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 10,
#   'eps': 600},
#  204: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 10,
#   'eps': 750},
#  205: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 11,
#   'eps': 300},
#  206: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 11,
#   'eps': 450},
#  207: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 11,
#   'eps': 600},
#  208: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 11,
#   'eps': 750},
#  209: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 12,
#   'eps': 300},
#  210: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 12,
#   'eps': 450},
#  211: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 12,
#   'eps': 600},
#  212: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 12,
#   'eps': 750},
#  213: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 13,
#   'eps': 300},
#  214: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 13,
#   'eps': 450},
#  215: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 13,
#   'eps': 600},
#  216: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 13,
#   'eps': 750},
#  217: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 14,
#   'eps': 300},
#  218: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 14,
#   'eps': 450},
#  219: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 14,
#   'eps': 600},
#  220: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 14,
#   'eps': 750},
#  221: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 15,
#   'eps': 300},
#  222: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 720},
#   'results': {'acc': 50.31, 'fp': 47.3, 'fn': 64.25},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 15,
# ...
#   'minSamples': 10,
#   'eps': 750},
#  927: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 11,
#   'eps': 300},
#  928: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 11,
#   'eps': 450},
#  929: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 11,
#   'eps': 600},
#  930: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 11,
#   'eps': 750},
#  931: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 12,
#   'eps': 300},
#  932: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 12,
#   'eps': 450},
#  933: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 12,
#   'eps': 600},
#  934: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 12,
#   'eps': 750},
#  935: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 13,
#   'eps': 300},
#  936: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 13,
#   'eps': 450},
#  937: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 13,
#   'eps': 600},
#  938: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 13,
#   'eps': 750},
#  939: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 14,
#   'eps': 300},
#  940: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 14,
#   'eps': 450},
#  941: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 14,
#   'eps': 600},
#  942: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 14,
#   'eps': 750},
#  943: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 15,
#   'eps': 300},
#  944: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 15,
#   'eps': 450},
#  945: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 15,
#   'eps': 600},
#  946: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 15,
#   'eps': 750},
#  947: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 16,
#   'eps': 300},
#  948: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 16,
#   'eps': 450},
#  949: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 16,
#   'eps': 600},
#  950: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 16,
#   'eps': 750},
#  951: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 17,
#   'eps': 300},
#  952: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 17,
#   'eps': 450},
#  953: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 17,
#   'eps': 600},
#  954: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 17,
#   'eps': 750},
#  955: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 18,
#   'eps': 300},
#  956: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 18,
#   'eps': 450},
#  957: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 18,
#   'eps': 600},
#  958: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 18,
#   'eps': 750},
#  959: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 19,
#   'eps': 300},
#  960: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 19,
#   'eps': 450},
#  961: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 19,
#   'eps': 600},
#  962: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.75,
#   'minSamples': 19,
#   'eps': 750},
#  963: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 8,
#   'eps': 300},
#  964: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 8,
#   'eps': 450},
#  965: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 8,
#   'eps': 600},
#  966: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 8,
#   'eps': 750},
#  967: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 9,
#   'eps': 300},
#  968: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 9,
#   'eps': 450},
#  969: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 9,
#   'eps': 600},
#  970: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 9,
#   'eps': 750},
#  971: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 10,
#   'eps': 300},
#  972: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 10,
#   'eps': 450},
#  973: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 10,
#   'eps': 600},
#  974: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 10,
#   'eps': 750},
#  975: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 11,
#   'eps': 300},
#  976: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 11,
#   'eps': 450},
#  977: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 11,
#   'eps': 600},
#  978: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 11,
#   'eps': 750},
#  979: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 12,
#   'eps': 300},
#  980: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 12,
#   'eps': 450},
#  981: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 12,
#   'eps': 600},
#  982: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 12,
#   'eps': 750},
#  983: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 13,
#   'eps': 300},
#  984: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 13,
#   'eps': 450},
#  985: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 13,
#   'eps': 600},
#  986: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 13,
#   'eps': 750},
#  987: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 14,
#   'eps': 300},
#  988: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 14,
#   'eps': 450},
#  989: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 14,
#   'eps': 600},
#  990: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 14,
#   'eps': 750},
#  991: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 15,
#   'eps': 300},
#  992: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 15,
#   'eps': 450},
#  993: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 15,
#   'eps': 600},
#  994: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 15,
#   'eps': 750},
#  995: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 16,
#   'eps': 300},
#  996: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 16,
#   'eps': 450},
#  997: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 16,
#   'eps': 600},
#  998: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 16,
#   'eps': 750},
#  999: {'detector': 'zscore',
#   'params': {'window_small': 5, 'window_large': 2160},
#   'results': {'acc': 50.35, 'fp': 48.86, 'fn': 64.72},
#   'clustering': True,
#   'percentile': 99.8,
#   'minSamples': 17,
#   'eps': 300},
#  ...}
